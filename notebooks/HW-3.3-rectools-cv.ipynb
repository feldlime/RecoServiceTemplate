# %%
import pandas as pd
import numpy as np
import scipy as sp
import requests
from tqdm.auto import tqdm
from scipy.stats import mode 
from pprint import pprint
from implicit.nearest_neighbours import CosineRecommender, TFIDFRecommender, BM25Recommender
import warnings
warnings.filterwarnings("ignore")

from rectools import Columns
from rectools.model_selection import TimeRangeSplitter
from rectools.dataset import Dataset, Interactions
from rectools.models.popular import PopularModel
from rectools.models.implicit_knn import ImplicitItemKNNWrapperModel
from rectools.metrics import Precision, Recall, MeanInvUserFreq, MAP, Serendipity, calc_metrics

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 200)

# %%
interactions = pd.read_csv('../data/kion_train/interactions.csv')

interactions.rename(columns={
        'last_watch_dt': Columns.Datetime,
        'total_dur': Columns.Weight
    }, 
    inplace=True
) 

interactions['datetime'] = pd.to_datetime(interactions['datetime'])

# %% [markdown]
# # Split

# %% [markdown]
# В соответствии с предположением из ноутбука "HW-3.1" сделаем **валидацию по 5 дней и по 7 дней**

# %%
def create_data_range(
    last_date: pd.Timestamp, 
    n_folds: int = 7, 
    unit: str = "W", 
    n_units: int = 1, 
    show: bool = True,
):
    periods = n_folds + 1
    freq = f"{n_units}{unit}"
    
    start_date = last_date - pd.Timedelta(n_folds * n_units + n_units, unit=unit)  
    
    date_range = pd.date_range(start=start_date, periods=periods, freq=freq, tz=last_date.tz)
    
    if show:
        print(
            f"start_date: {start_date}\n"
            f"last_date: {last_date}\n"
            f"periods: {periods}\n"
            f"freq: {freq}\n"
            f"Test fold borders: {date_range.values.astype('datetime64[D]')}\n"
        )
        
    return date_range

# %%
CONFIG_CV = {
    "cv_v1": {
        "n_folds": 5,
        "unit": "W",
        "n_units": 1,
    },
    "cv_v2": {
        "n_folds": 5,
        "unit": "D",
        "n_units": 5,
    }, 
}

# %%
last_date = interactions[Columns.Datetime].max().normalize()
last_date
# Out:
# Timestamp('2021-08-22 00:00:00')

# %%
print("***Folds v1***")
date_range_v1 = create_data_range(
    last_date, 
    n_folds=CONFIG_CV["cv_v1"]["n_folds"], 
    unit=CONFIG_CV["cv_v1"]["unit"], 
    n_units=CONFIG_CV["cv_v1"]["n_units"]
)

print("***Folds v2***")
date_range_v2 = create_data_range(
    last_date, 
    n_folds=CONFIG_CV["cv_v2"]["n_folds"], 
    unit=CONFIG_CV["cv_v2"]["unit"], 
    n_units=CONFIG_CV["cv_v2"]["n_units"]
)
# Out:
# ***Folds v1***
# start_date: 2021-07-11 00:00:00
# last_date: 2021-08-22 00:00:00
# periods: 6
# freq: 1W
# Test fold borders: ['2021-07-11' '2021-07-18' '2021-07-25' '2021-08-01' '2021-08-08'
#  '2021-08-15']
#
# ***Folds v2***
# start_date: 2021-07-23 00:00:00
# last_date: 2021-08-22 00:00:00
# periods: 6
# freq: 5D
# Test fold borders: ['2021-07-23' '2021-07-28' '2021-08-02' '2021-08-07' '2021-08-12'
#  '2021-08-17']

# %%
cv_v1 = TimeRangeSplitter(
    date_range=date_range_v1,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)
print(f"Real number of folds: {cv_v1.get_n_splits(Interactions(interactions))}")

cv_v2 = TimeRangeSplitter(
    date_range=date_range_v2,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)
print(f"Real number of folds: {cv_v2.get_n_splits(Interactions(interactions))}")

CV = [cv_v1, cv_v2]
# Out:
# Real number of folds: 5
# Real number of folds: 5

# %%
metrics = {
    "prec@5": Precision(k=5),
    "recall@5": Recall(k=5),
    "MAP@5": MAP(k=5),
    "prec@10": Precision(k=10),
    "recall@10": Recall(k=10),
    "MAP@10": MAP(k=10),
    "novelty": MeanInvUserFreq(k=10),
    "serendipity": Serendipity(k=10),
}

# %% [markdown]
# # Find best models

# %%
K = [30, 40, 50, 60]
models = {
    "popular": PopularModel(),
    "popular_mw": PopularModel(popularity="mean_weight")
}

for k in K:
    models[f"popular"]
    models[f"cosine_userknn_K{k}"] = ImplicitItemKNNWrapperModel(model=CosineRecommender(K=k))
    models[f"tfidf_userknn_K{k}"] = ImplicitItemKNNWrapperModel(model=TFIDFRecommender(K=k))
    models[f"bm25_userknn_K{k}"] = ImplicitItemKNNWrapperModel(model=BM25Recommender(K=k))

models
# Out:
# {'popular': <rectools.models.popular.PopularModel at 0x7f753b9a29d0>,
#  'popular_mw': <rectools.models.popular.PopularModel at 0x7f753b9a2190>,
#  'cosine_userknn_K30': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b9a2400>,
#  'tfidf_userknn_K30': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b9a24f0>,
#  'bm25_userknn_K30': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b9a2940>,
#  'cosine_userknn_K40': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b982280>,
#  'tfidf_userknn_K40': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b982430>,
#  'bm25_userknn_K40': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b982520>,
#  'cosine_userknn_K50': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b982670>,
#  'tfidf_userknn_K50': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b9826d0>,
#  'bm25_userknn_K50': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b9828b0>,
#  'cosine_userknn_K60': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b9829d0>,
#  'tfidf_userknn_K60': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b982880>,
#  'bm25_userknn_K60': <rectools.models.implicit_knn.ImplicitItemKNNWrapperModel at 0x7f753b982940>}

# %%
# %%time

results = []
K_RECOS = 10
for idx, cv in enumerate(CV):
    print(f"\n ***CV_{idx}***")
    fold_iterator = cv.split(Interactions(interactions), collect_fold_stats=True)

    for i_fold, (train_ids, test_ids, fold_info) in enumerate(fold_iterator):
        print(f"\n==================== Fold {i_fold}")
        pprint(fold_info)

        train = interactions.iloc[train_ids].copy()
        test = interactions.iloc[test_ids][Columns.UserItem].copy()

        dataset = Dataset.construct(
            interactions_df=train,
            user_features_df=None,
            item_features_df=None
        )
        
        catalog = train[Columns.Item].unique()
        
        
        for model_name, model in tqdm(models.items()):
            model.fit(dataset)
            
            for filter_viewed in [False, True]: # предсказывать одинаковые item-ы для всех юзеров?
                model_quality = {"fold": i_fold, "model": f"{model_name}_view-{filter_viewed}"}
                recos_curr = model.recommend(
                    users=test[Columns.User].unique(),
                    dataset=dataset,
                    k=K_RECOS,
                    filter_viewed=filter_viewed,
                )

                metric_values = calc_metrics(
                    metrics,
                    reco=recos_curr,
                    interactions=test,
                    prev_interactions=train,
                    catalog=catalog
                )
                model_quality.update(metric_values)
                results.append(model_quality)
# Out:
#  ***CV_0***
#
# ==================== Fold 0
# {'End date': Timestamp('2021-07-18 00:00:00', freq='W-SUN'),
#  'Start date': Timestamp('2021-07-11 00:00:00', freq='W-SUN'),
#  'Test': 214489,
#  'Test items': 6313,
#  'Test users': 84234,
#  'Train': 3192875,
#  'Train items': 14711,
#  'Train users': 640144}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 1
# {'End date': Timestamp('2021-07-25 00:00:00', freq='W-SUN'),
#  'Start date': Timestamp('2021-07-18 00:00:00', freq='W-SUN'),
#  'Test': 231207,
#  'Test items': 6491,
#  'Test users': 87632,
#  'Train': 3506106,
#  'Train items': 14928,
#  'Train users': 687200}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 2
# {'End date': Timestamp('2021-08-01 00:00:00', freq='W-SUN'),
#  'Start date': Timestamp('2021-07-25 00:00:00', freq='W-SUN'),
#  'Test': 249396,
#  'Test items': 6611,
#  'Test users': 93092,
#  'Train': 3838180,
#  'Train items': 15061,
#  'Train users': 734701}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 3
# {'End date': Timestamp('2021-08-08 00:00:00', freq='W-SUN'),
#  'Start date': Timestamp('2021-08-01 00:00:00', freq='W-SUN'),
#  'Test': 264039,
#  'Test items': 6609,
#  'Test users': 98161,
#  'Train': 4203885,
#  'Train items': 15212,
#  'Train users': 788721}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 4
# {'End date': Timestamp('2021-08-15 00:00:00', freq='W-SUN'),
#  'Start date': Timestamp('2021-08-08 00:00:00', freq='W-SUN'),
#  'Test': 276699,
#  'Test items': 6715,
#  'Test users': 101983,
#  'Train': 4587708,
#  'Train items': 15404,
#  'Train users': 842129}
#   0%|          | 0/14 [00:00<?, ?it/s]
#  ***CV_1***
#
# ==================== Fold 0
# {'End date': Timestamp('2021-07-28 00:00:00', freq='5D'),
#  'Start date': Timestamp('2021-07-23 00:00:00', freq='5D'),
#  'Test': 175051,
#  'Test items': 6088,
#  'Test users': 72916,
#  'Train': 3740952,
#  'Train items': 15017,
#  'Train users': 720875}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 1
# {'End date': Timestamp('2021-08-02 00:00:00', freq='5D'),
#  'Start date': Timestamp('2021-07-28 00:00:00', freq='5D'),
#  'Test': 194020,
#  'Test items': 6211,
#  'Test users': 80145,
#  'Train': 3990413,
#  'Train items': 15128,
#  'Train users': 756988}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 2
# {'End date': Timestamp('2021-08-07 00:00:00', freq='5D'),
#  'Start date': Timestamp('2021-08-02 00:00:00', freq='5D'),
#  'Test': 187734,
#  'Test items': 6024,
#  'Test users': 78089,
#  'Train': 4266013,
#  'Train items': 15237,
#  'Train users': 797423}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 3
# {'End date': Timestamp('2021-08-12 00:00:00', freq='5D'),
#  'Start date': Timestamp('2021-08-07 00:00:00', freq='5D'),
#  'Test': 206420,
#  'Test items': 6179,
#  'Test users': 83403,
#  'Train': 4528392,
#  'Train items': 15385,
#  'Train users': 833905}
#   0%|          | 0/14 [00:00<?, ?it/s]
# ==================== Fold 4
# {'End date': Timestamp('2021-08-17 00:00:00', freq='5D'),
#  'Start date': Timestamp('2021-08-12 00:00:00', freq='5D'),
#  'Test': 209972,
#  'Test items': 6248,
#  'Test users': 86532,
#  'Train': 4811285,
#  'Train items': 15499,
#  'Train users': 872587}
#   0%|          | 0/14 [00:00<?, ?it/s]
# CPU times: user 40min 56s, sys: 14.7 s, total: 41min 11s
# Wall time: 39min 47s

# %% [markdown]
# ## Show metrics

# %%
df_metrics = pd.DataFrame(results)

df_metrics['cv'] = 'fold_1w'
df_metrics.loc[df_metrics[240:].index, 'cv'] = 'fold_5d'

df_metrics
# Out:
#      fold                          model    prec@5  recall@5   prec@10  \
# 0       0             popular_view-False  0.057927  0.165644  0.040750
# 1       0              popular_view-True  0.067068  0.187785  0.043174
# 2       0          popular_mw_view-False  0.000000  0.000000  0.000000
# 3       0           popular_mw_view-True  0.000000  0.000000  0.000000
# 4       0  cosine_userknn_K30_view-False  0.023309  0.073918  0.022143
# ..    ...                            ...       ...       ...       ...
# 275     4   cosine_userknn_K60_view-True  0.030860  0.087797  0.023432
# 276     4   tfidf_userknn_K60_view-False  0.019757  0.060871  0.021400
# 277     4    tfidf_userknn_K60_view-True  0.042803  0.116265  0.032173
# 278     4    bm25_userknn_K60_view-False  0.037006  0.107442  0.028958
# 279     4     bm25_userknn_K60_view-True  0.049568  0.139971  0.034646
#
#      recall@10     MAP@5    MAP@10    novelty  serendipity       cv
# 0     0.225673  0.081512  0.091268   3.527632     0.000000  fold_1w
# 1     0.236855  0.106416  0.114674   3.770513     0.000003  fold_1w
# 2     0.000000  0.000000  0.000000  18.225101     0.000000  fold_1w
# 3     0.000000  0.000000  0.000000  18.225113     0.000000  fold_1w
# 4     0.129775  0.024364  0.032651   7.914110     0.000048  fold_1w
# ..         ...       ...       ...        ...          ...      ...
# 275   0.129578  0.052772  0.059091   9.152968     0.000122  fold_5d
# 276   0.122260  0.019698  0.028557   6.651334     0.000095  fold_5d
# 277   0.170458  0.069460  0.077912   6.727128     0.000180  fold_5d
# 278   0.162346  0.037895  0.046199   3.920584     0.000024  fold_5d
# 279   0.191827  0.084181  0.092022   4.002574     0.000038  fold_5d
#
# [280 rows x 11 columns]

# %%
df_metrics_mean = df_metrics.groupby(['cv', 'model'])[
    'prec@5', 'recall@5', 'prec@10', 'recall@10', 'MAP@5', 'MAP@10', 'novelty', 'serendipity'
].mean()

df_metrics_mean.style.highlight_max(color='lightgreen', axis=0)
# Out:
# <style type="text/css">
# #T_f67e4_row7_col0, #T_f67e4_row7_col1, #T_f67e4_row7_col2, #T_f67e4_row7_col3, #T_f67e4_row7_col4, #T_f67e4_row7_col5, #T_f67e4_row45_col6, #T_f67e4_row49_col7 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f67e4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f67e4_level0_col0" class="col_heading level0 col0" >prec@5</th>
#       <th id="T_f67e4_level0_col1" class="col_heading level0 col1" >recall@5</th>
#       <th id="T_f67e4_level0_col2" class="col_heading level0 col2" >prec@10</th>
#       <th id="T_f67e4_level0_col3" class="col_heading level0 col3" >recall@10</th>
#       <th id="T_f67e4_level0_col4" class="col_heading level0 col4" >MAP@5</th>
#       <th id="T_f67e4_level0_col5" class="col_heading level0 col5" >MAP@10</th>
#       <th id="T_f67e4_level0_col6" class="col_heading level0 col6" >novelty</th>
#       <th id="T_f67e4_level0_col7" class="col_heading level0 col7" >serendipity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cv</th>
#       <th class="index_name level1" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f67e4_level0_row0" class="row_heading level0 row0" rowspan="28">fold_1w</th>
#       <th id="T_f67e4_level1_row0" class="row_heading level1 row0" >bm25_userknn_K30_view-False</th>
#       <td id="T_f67e4_row0_col0" class="data row0 col0" >0.042185</td>
#       <td id="T_f67e4_row0_col1" class="data row0 col1" >0.119823</td>
#       <td id="T_f67e4_row0_col2" class="data row0 col2" >0.034154</td>
#       <td id="T_f67e4_row0_col3" class="data row0 col3" >0.185347</td>
#       <td id="T_f67e4_row0_col4" class="data row0 col4" >0.042525</td>
#       <td id="T_f67e4_row0_col5" class="data row0 col5" >0.052672</td>
#       <td id="T_f67e4_row0_col6" class="data row0 col6" >3.946248</td>
#       <td id="T_f67e4_row0_col7" class="data row0 col7" >0.000025</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row1" class="row_heading level1 row1" >bm25_userknn_K30_view-True</th>
#       <td id="T_f67e4_row1_col0" class="data row1 col0" >0.057809</td>
#       <td id="T_f67e4_row1_col1" class="data row1 col1" >0.158462</td>
#       <td id="T_f67e4_row1_col2" class="data row1 col2" >0.039961</td>
#       <td id="T_f67e4_row1_col3" class="data row1 col3" >0.213474</td>
#       <td id="T_f67e4_row1_col4" class="data row1 col4" >0.095232</td>
#       <td id="T_f67e4_row1_col5" class="data row1 col5" >0.103942</td>
#       <td id="T_f67e4_row1_col6" class="data row1 col6" >4.022938</td>
#       <td id="T_f67e4_row1_col7" class="data row1 col7" >0.000040</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row2" class="row_heading level1 row2" >bm25_userknn_K40_view-False</th>
#       <td id="T_f67e4_row2_col0" class="data row2 col0" >0.042144</td>
#       <td id="T_f67e4_row2_col1" class="data row2 col1" >0.119736</td>
#       <td id="T_f67e4_row2_col2" class="data row2 col2" >0.034143</td>
#       <td id="T_f67e4_row2_col3" class="data row2 col3" >0.185324</td>
#       <td id="T_f67e4_row2_col4" class="data row2 col4" >0.042480</td>
#       <td id="T_f67e4_row2_col5" class="data row2 col5" >0.052632</td>
#       <td id="T_f67e4_row2_col6" class="data row2 col6" >3.946874</td>
#       <td id="T_f67e4_row2_col7" class="data row2 col7" >0.000024</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row3" class="row_heading level1 row3" >bm25_userknn_K40_view-True</th>
#       <td id="T_f67e4_row3_col0" class="data row3 col0" >0.057809</td>
#       <td id="T_f67e4_row3_col1" class="data row3 col1" >0.158459</td>
#       <td id="T_f67e4_row3_col2" class="data row3 col2" >0.039978</td>
#       <td id="T_f67e4_row3_col3" class="data row3 col3" >0.213672</td>
#       <td id="T_f67e4_row3_col4" class="data row3 col4" >0.095225</td>
#       <td id="T_f67e4_row3_col5" class="data row3 col5" >0.103958</td>
#       <td id="T_f67e4_row3_col6" class="data row3 col6" >4.019052</td>
#       <td id="T_f67e4_row3_col7" class="data row3 col7" >0.000040</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row4" class="row_heading level1 row4" >bm25_userknn_K50_view-False</th>
#       <td id="T_f67e4_row4_col0" class="data row4 col0" >0.042758</td>
#       <td id="T_f67e4_row4_col1" class="data row4 col1" >0.121282</td>
#       <td id="T_f67e4_row4_col2" class="data row4 col2" >0.034677</td>
#       <td id="T_f67e4_row4_col3" class="data row4 col3" >0.187847</td>
#       <td id="T_f67e4_row4_col4" class="data row4 col4" >0.043014</td>
#       <td id="T_f67e4_row4_col5" class="data row4 col5" >0.053338</td>
#       <td id="T_f67e4_row4_col6" class="data row4 col6" >3.952222</td>
#       <td id="T_f67e4_row4_col7" class="data row4 col7" >0.000024</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row5" class="row_heading level1 row5" >bm25_userknn_K50_view-True</th>
#       <td id="T_f67e4_row5_col0" class="data row5 col0" >0.058727</td>
#       <td id="T_f67e4_row5_col1" class="data row5 col1" >0.160635</td>
#       <td id="T_f67e4_row5_col2" class="data row5 col2" >0.040486</td>
#       <td id="T_f67e4_row5_col3" class="data row5 col3" >0.215923</td>
#       <td id="T_f67e4_row5_col4" class="data row5 col4" >0.096576</td>
#       <td id="T_f67e4_row5_col5" class="data row5 col5" >0.105357</td>
#       <td id="T_f67e4_row5_col6" class="data row5 col6" >4.019601</td>
#       <td id="T_f67e4_row5_col7" class="data row5 col7" >0.000040</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row6" class="row_heading level1 row6" >bm25_userknn_K60_view-False</th>
#       <td id="T_f67e4_row6_col0" class="data row6 col0" >0.042737</td>
#       <td id="T_f67e4_row6_col1" class="data row6 col1" >0.121230</td>
#       <td id="T_f67e4_row6_col2" class="data row6 col2" >0.034666</td>
#       <td id="T_f67e4_row6_col3" class="data row6 col3" >0.187796</td>
#       <td id="T_f67e4_row6_col4" class="data row6 col4" >0.042991</td>
#       <td id="T_f67e4_row6_col5" class="data row6 col5" >0.053314</td>
#       <td id="T_f67e4_row6_col6" class="data row6 col6" >3.954001</td>
#       <td id="T_f67e4_row6_col7" class="data row6 col7" >0.000024</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row7" class="row_heading level1 row7" >bm25_userknn_K60_view-True</th>
#       <td id="T_f67e4_row7_col0" class="data row7 col0" >0.058733</td>
#       <td id="T_f67e4_row7_col1" class="data row7 col1" >0.160645</td>
#       <td id="T_f67e4_row7_col2" class="data row7 col2" >0.040489</td>
#       <td id="T_f67e4_row7_col3" class="data row7 col3" >0.215989</td>
#       <td id="T_f67e4_row7_col4" class="data row7 col4" >0.096582</td>
#       <td id="T_f67e4_row7_col5" class="data row7 col5" >0.105369</td>
#       <td id="T_f67e4_row7_col6" class="data row7 col6" >4.019745</td>
#       <td id="T_f67e4_row7_col7" class="data row7 col7" >0.000040</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row8" class="row_heading level1 row8" >cosine_userknn_K30_view-False</th>
#       <td id="T_f67e4_row8_col0" class="data row8 col0" >0.018253</td>
#       <td id="T_f67e4_row8_col1" class="data row8 col1" >0.056689</td>
#       <td id="T_f67e4_row8_col2" class="data row8 col2" >0.018359</td>
#       <td id="T_f67e4_row8_col3" class="data row8 col3" >0.105630</td>
#       <td id="T_f67e4_row8_col4" class="data row8 col4" >0.018688</td>
#       <td id="T_f67e4_row8_col5" class="data row8 col5" >0.025865</td>
#       <td id="T_f67e4_row8_col6" class="data row8 col6" >8.017523</td>
#       <td id="T_f67e4_row8_col7" class="data row8 col7" >0.000059</td>
#     </tr>
#     <tr>
#       <th id="T_f67e4_level1_row9" class="row_heading level1 row9" >cosine_userknn_K30_view-True</th>
#       <td id="T_f67e4_row9_col0" class="data row9 col0" >0.035555</td>
#       <td id="T_f67e4_row9_col1" class="data row9 col1

# %% [markdown]
# Из результатов видно, что среднее значение метрик моделей **bmp** имеют **наилучшие** значения, причем на недельном фолде метрики выше, чем на 5 дневном
#
# - Следует проверить статистически различимы значения или нет. Для этого следует посмотреть дисперсию и если дисперсия меньше чем различия между средними значениями метрик, то можно сделать вывод, что значения метрик статистически различны

# %%
df_metrics_std = df_metrics.groupby(['cv', 'model'])[
    'prec@5', 'recall@5', 'prec@10', 'recall@10', 'MAP@5', 'MAP@10', 'novelty', 'serendipity'
].std()

df_metrics_std
# Out:
#                                          prec@5  recall@5   prec@10  \
# cv      model
# fold_1w bm25_userknn_K30_view-False    0.004042  0.011380  0.003319
#         bm25_userknn_K30_view-True     0.005348  0.014587  0.002787
#         bm25_userknn_K40_view-False    0.004036  0.011393  0.003310
#         bm25_userknn_K40_view-True     0.005334  0.014592  0.002774
#         bm25_userknn_K50_view-False    0.003777  0.011013  0.003087
#         bm25_userknn_K50_view-True     0.004894  0.013955  0.002467
#         bm25_userknn_K60_view-False    0.003774  0.011002  0.003088
#         bm25_userknn_K60_view-True     0.004894  0.013963  0.002466
#         cosine_userknn_K30_view-False  0.002393  0.007803  0.001918
#         cosine_userknn_K30_view-True   0.003624  0.010400  0.001786
#         cosine_userknn_K40_view-False  0.002389  0.007794  0.001908
#         cosine_userknn_K40_view-True   0.003568  0.010257  0.001752
#         cosine_userknn_K50_view-False  0.002316  0.007773  0.001844
#         cosine_userknn_K50_view-True   0.003382  0.010032  0.001646
#         cosine_userknn_K60_view-False  0.002314  0.007792  0.001859
#         cosine_userknn_K60_view-True   0.003404  0.010088  0.001638
#         popular_mw_view-False          0.000002  0.000006  0.000001
#         popular_mw_view-True           0.000002  0.000006  0.000001
#         popular_view-False             0.005212  0.014572  0.003829
#         popular_view-True              0.006104  0.016656  0.003793
#         tfidf_userknn_K30_view-False   0.002244  0.006995  0.001945
#         tfidf_userknn_K30_view-True    0.003332  0.009001  0.001968
#         tfidf_userknn_K40_view-False   0.002247  0.007018  0.001933
#         tfidf_userknn_K40_view-True    0.003319  0.008904  0.001924
#         tfidf_userknn_K50_view-False   0.002201  0.007068  0.001885
#         tfidf_userknn_K50_view-True    0.003195  0.008819  0.001801
#         tfidf_userknn_K60_view-False   0.002204  0.007088  0.001886
#         tfidf_userknn_K60_view-True    0.003199  0.008829  0.001809
# fold_5d bm25_userknn_K30_view-False         NaN       NaN       NaN
#         bm25_userknn_K30_view-True          NaN       NaN       NaN
#         bm25_userknn_K40_view-False         NaN       NaN       NaN
#         bm25_userknn_K40_view-True          NaN       NaN       NaN
#         bm25_userknn_K50_view-False    0.000039  0.000456  0.000612
#         bm25_userknn_K50_view-True     0.000697  0.000847  0.000817
#         bm25_userknn_K60_view-False    0.000031  0.000458  0.000616
#         bm25_userknn_K60_view-True     0.000706  0.000869  0.000850
#         cosine_userknn_K30_view-False       NaN       NaN       NaN
#         cosine_userknn_K30_view-True        NaN       NaN       NaN
#         cosine_userknn_K40_view-False       NaN       NaN       NaN
#         cosine_userknn_K40_view-True        NaN       NaN       NaN
#         cosine_userknn_K50_view-False  0.000355  0.000981  0.000706
#         cosine_userknn_K50_view-True   0.000792  0.001468  0.000966
#         cosine_userknn_K60_view-False  0.000377  0.001029  0.000735
#         cosine_userknn_K60_view-True   0.000810  0.001555  0.001006
#         popular_mw_view-False               NaN       NaN       NaN
#         popular_mw_view-True                NaN       NaN       NaN
#         popular_view-False                  NaN       NaN       NaN
#         popular_view-True                   NaN       NaN       NaN
#         tfidf_userknn_K30_view-False        NaN       NaN       NaN
#         tfidf_userknn_K30_view-True         NaN       NaN       NaN
#         tfidf_userknn_K40_view-False        NaN       NaN       NaN
#         tfidf_userknn_K40_view-True         NaN       NaN       NaN
#         tfidf_userknn_K50_view-False   0.000568  0.001477  0.000563
#         tfidf_userknn_K50_view-True    0.000655  0.001235  0.000746
#         tfidf_userknn_K60_view-False   0.000517  0.001370  0.000578
#         tfidf_userknn_K60_view-True    0.000630  0.001230  0.000742
#
#                                        recall@10     MAP@5    MAP@10  \
# cv      model
# fold_1w bm25_userknn_K30_view-False     0.018050  0.004144  0.005235
#         bm25_userknn_K30_view-True      0.013620  0.009823  0.009871
#         bm25_userknn_K40_view-False     0.018033  0.004149  0.005234
#         bm25_userknn_K40_view-True      0.013511  0.009824  0.009859
#         bm25_userknn_K50_view-False     0.017476  0.004039  0.005071
#         bm25_userknn_K50_view-True      0.012485  0.009562  0.009532
#         bm25_userknn_K60_view-False     0.017492  0.004038  0.005074
#         bm25_userknn_K60_view-True      0.012478  0.009562  0.009529
#         cosine_userknn_K30_view-False   0.011326  0.002518  0.003091
#         cosine_userknn_K30_view-True    0.008810  0.007000  0.006842
#         cosine_userknn_K40_view-False   0.011295  0.002517  0.003081
#         cosine_userknn_K40_view-True    0.008547  0.006951  0.006784
#         cosine_userknn_K50_view-False   0.011284  0.002512  0.003072
#         cosine_userknn_K50_view-True    0.008276  0.006918  0.006730
#         cosine_userknn_K60_view-False   0.011354  0.002514  0.003083
#         cosine_userknn_K60_view-True    0.008246  0.006961  0.006769
#         popular_mw_view-False           0.000005  0.000002  0.000002
#         popular_mw_view-True            0.000005  0.000002  0.000002
#         popular_view-False              0.021739  0.006100  0.007075
#         popular_view-True               0.020875  0.008955  0.009653
#         tfidf_userknn_K30_view-False    0.010664  0.002381  0.002965
#         tfidf_userknn_K30_view-True     0.008611  0.006374  0.006390
#         tfidf_userknn_K40_view-False    0.010582  0.002384  0.002949
#         tfidf_userknn_K40_view-True     0.008288  0.006300  0.006288
#         tfidf_userknn_K50_view-False    0.010591  0.002401  0.002955
#         tfidf_userknn_K50_view-True     0.007796  0.006357  0.006279
#         tfidf_userknn_K60_view-False    0.010659  0.002412  0.002972
#         tfidf_userknn_K60_view-True     0.007841  0.006420  0.006348
# fold_5d bm25_userknn_K30_view-False          NaN       NaN       NaN
#         bm25_userknn_K30_view-True           NaN       NaN       NaN
#         bm25_userknn_K40_view-False          NaN       NaN       NaN
#         bm25_userknn_K40_view-True           NaN       NaN       NaN
#         bm25_userknn_K50_view-False     0.001867  0.000002  0.000366
#         bm25_userknn_K50_view-True      0.002536  0.000228  0.000552
#         bm25_userknn_K60_view-False     0.001841  0.000013  0.000375
#         bm25_userknn_K60_view-True      0.002691  0.000232  0.000569
#         cosine_userknn_K30_view-False        NaN       NaN       NaN
#         cosine_userknn_K30_view-True         NaN       NaN       NaN
#         cosine_userknn_K40_view-False        NaN       NaN       NaN
#         cosine_userknn_K40_view-True         NaN       NaN       NaN
#         cosine_userknn_K50_view-False   0.003366  0.000412  0.000798
#         cosine_userknn_K50_view-True    0.004740  0.001308  0.001817
#         cosine_userknn_K60_view-False   0.003548  0.000427  0.000831
#         cosine_userknn_K60_view-True    0.005148  0.001363  0.001908
#         popular_mw_view-False                NaN       NaN       NaN
#         popular_mw_view-True                 NaN       NaN       NaN
#         popular_view-False                   NaN       NaN       NaN
#         popular_view-True                    NaN       NaN       NaN
#         tfidf_userknn_K30_view-False         NaN       NaN       NaN
#         tfidf_userknn_K30_view-True          NaN       NaN       NaN
#         tfidf_userknn_K40_view-False         NaN       NaN       NaN
#         tfidf_userknn_K40_view-True          NaN       NaN       NaN
#         tfidf_userknn_K50_view-False    0.002622  0.000637  0.000848
#         tfidf_userknn_K50_view-True     0.003303  0.001587  0.001903
#         tfidf_userknn_K60_view-False    0.002855  0.000619  0.000868
#         tfidf_userknn_K60_view-True     0.003273  0.001598  0.001922
#
#                                         novelty   serendipity
# cv      model
# fold_1w bm25_userknn_K30_view-False    0.029730  1.677056e-06
#         bm25_userknn_K30_view-True     0.015006  3.357219e-06
#         bm25_userknn_K40_view-False    0.029613  1.666772e-06
#         bm25_userknn_K40_view-True     0.014709  3.359684e-06
#         bm25_userknn_K50_view-False    0.029329  1.807696e-06
#         bm25_userknn_K50_view-True     0.014861  3.329699e-06
#         bm25_userknn_K60_view-False    0.029368  1.805538e-06
#         bm25_userknn_K60_view-True     0.014738  3.340070e-06
#         cosine_userknn_K30_view-False  0.047337  5.304930e-06
#         cosine_userknn_K30_view-True   0.047027  9.087191e-06
#         cosine_userknn_K40_view-False  0.046445  5.302222e-06
#         cosine_userknn_K40_view-True   0.046824  9.276498e-06
#         cosine_userknn_K50_view-False  0.046345  5.581875e-06
#         cosine_userknn_K50_view-True   0.046799  9.814832e-06
#         cosine_userknn_K60_view-False  0.046454  5.564036e-06
#         cosine_userknn_K60_view-True   0.047133  9.793017e-06
#         popular_mw_view-False          0.125158  1.003157e-07
#         popular_mw_view-True           0.125155  1.003157e-07
#         popular_view-False             0.030175  0.000000e+00
#         popular_view-True              0.019131  2.429424e-07
#         tfidf_userknn_K30_view-False   0.039877  8.695037e-06
#         tfidf_userknn_K30_view-True    0.069638  1.279797e-05
#         tfidf_userknn_K40_view-False   0.040851  8.509896e-06
#         tfidf_userknn_K40_view-True    0.070819  1.317232e-05
#         tfidf_userknn_K50_view-False   0.040492  8.580259e-06
#         tfidf_userknn_K50_view-True    0.065490  1.351216e-05
#         tfidf_userknn_K60_view-False   0.040827  8.400699e-06
#         tfidf_userknn_K60_view-True    0.066050  1.359432e-05
# fold_5d bm25_userknn_K30_view-False         NaN           NaN
#         bm25_userknn_K30_view-True          NaN           NaN
#         bm25_userknn_K40_view-False         NaN           NaN
#         bm25_userknn_K40_view-True          NaN           NaN
#         bm25_userknn_K50_view-False    0.000725  1.109718e-07
#         bm25_userknn_K50_view-True     0.001242  8.703289e-07
#         bm25_userknn_K60_view-False    0.000543  8.345726e-08
#         bm25_userknn_K60_view-True     0.001734  1.165137e-06
#         cosine_userknn_K30_view-False       NaN           NaN
#         cosine_userknn_K30_view-True        NaN           NaN
#         cosine_userknn_K40_view-False       NaN           NaN
#         cosine_userknn_K40_view-True        NaN           NaN
#         cosine_userknn_K50_view-False  0.001041  6.443968e-07
#         cosine_userknn_K50_view-True   0.018350  2.644474e-06
#         cosine_userknn_K60_view-False  0.003236  7.481876e-07
#         cosine_userknn_K60_view-True   0.018208  2.395850e-06
#         popular_mw_view-False               NaN           NaN
#         popular_mw_view-True                NaN           NaN
#         popular_view-False                  NaN           NaN
#         popular_view-True                   NaN           NaN
#         tfidf_userknn_K30_view-False        NaN           NaN
#         tfidf_userknn_K30_view-True         NaN           NaN
#         tfidf_userknn_K40_view-False        NaN           NaN
#         tfidf_userknn_K40_view-True         NaN           NaN
#         tfidf_userknn_K50_view-False   0.014073  1.071478e-06
#         tfidf_userknn_K50_view-True    0.028847  3.757778e-06
#         tfidf_userknn_K60_view-False   0.013426  1.001711e-06
#         tfidf_userknn_K60_view-True    0.029335  4.434436e-06

# %%
df_metrics_1w_mean = df_metrics_mean.loc["fold_1w"]
df_metrics_1w_std = df_metrics_std.loc["fold_1w"]

# %%
best_model = "bm25_userknn_K60_view-True"
col_metrics = list(metrics.keys())
std_best_metrics = df_metrics_1w_std[df_metrics_1w_std["model"] == best_model][col_metrics].values[0]

# %%
print(df_metrics_1w_std.loc[best_model])
for model in df_metrics_1w_mean.index:
    if model != best_model:
        print(f"\n===Сравнение с {model}")
        print(df_metrics_1w_mean.loc[best_model] - df_metrics_1w_mean.loc[model])
        print("=========================")
# Out:
# prec@5         0.004894
# recall@5       0.013963
# prec@10        0.002466
# recall@10      0.012478
# MAP@5          0.009562
# MAP@10         0.009529
# novelty        0.014738
# serendipity    0.000003
# Name: bm25_userknn_K60_view-True, dtype: float64
#
# ===Сравнение с bm25_userknn_K30_view-False
# prec@5         0.000852
# recall@5       0.002584
# prec@10       -0.000854
# recall@10     -0.005571
# MAP@5          0.005418
# MAP@10         0.004293
# novelty       -0.014992
# serendipity    0.000002
# dtype: float64
# =========================
#
# ===Сравнение с bm25_userknn_K30_view-True
# prec@5        -4.545181e-04
# recall@5      -6.232778e-04
# prec@10       -3.208519e-04
# recall@10     -1.141463e-03
# MAP@5         -2.606624e-04
# MAP@10        -3.423636e-04
# novelty       -2.682734e-04
# serendipity   -1.714842e-08
# dtype: float64
# =========================
#
# ===Сравнение с bm25_userknn_K40_view-False
# prec@5         0.000858
# recall@5       0.002570
# prec@10       -0.000844
# recall@10     -0.005554
# MAP@5          0.005413
# MAP@10         0.004294
# novelty       -0.014875
# serendipity    0.000002
# dtype: float64
# =========================
#
# ===Сравнение с bm25_userknn_K40_view-True
# prec@5        -4.403880e-04
# recall@5      -6.290758e-04
# prec@10       -3.080923e-04
# recall@10     -1.032860e-03
# MAP@5         -2.622039e-04
# MAP@10        -3.305713e-04
# novelty        2.940168e-05
# serendipity   -1.961419e-08
# dtype: float64
# =========================
#
# ===Сравнение с bm25_userknn_K50_view-False
# prec@5         0.001117
# recall@5       0.002950
# prec@10       -0.000621
# recall@10     -0.004998
# MAP@5          0.005523
# MAP@10         0.004457
# novelty       -0.014591
# serendipity    0.000002
# dtype: float64
# =========================
#
# ===Сравнение с bm25_userknn_K50_view-True
# prec@5        -6.188074e-08
# recall@5       8.340206e-06
# prec@10       -1.581047e-06
# recall@10     -6.557768e-06
# MAP@5          8.532418e-08
# MAP@10        -3.212381e-06
# novelty       -1.225529e-04
# serendipity    1.037090e-08
# dtype: float64
# =========================
#
# ===Сравнение с bm25_userknn_K60_view-False
# prec@5         0.001119
# recall@5       0.002961
# prec@10       -0.000622
# recall@10     -0.005014
# MAP@5          0.005524
# MAP@10         0.004455
# novelty       -0.014630
# serendipity    0.000002
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K30_view-False
# prec@5         0.002501
# recall@5       0.006161
# prec@10        0.000548
# recall@10      0.001152
# MAP@5          0.007044
# MAP@10         0.006437
# novelty       -0.032599
# serendipity   -0.000002
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K30_view-True
# prec@5         0.001270
# recall@5       0.003563
# prec@10        0.000680
# recall@10      0.003668
# MAP@5          0.002563
# MAP@10         0.002687
# novelty       -0.032289
# serendipity   -0.000006
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K40_view-False
# prec@5         0.002504
# recall@5       0.006169
# prec@10        0.000558
# recall@10      0.001184
# MAP@5          0.007046
# MAP@10         0.006448
# novelty       -0.031707
# serendipity   -0.000002
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K40_view-True
# prec@5         0.001325
# recall@5       0.003706
# prec@10        0.000714
# recall@10      0.003931
# MAP@5          0.002611
# MAP@10         0.002744
# novelty       -0.032086
# serendipity   -0.000006
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K50_view-False
# prec@5         0.002578
# recall@5       0.006190
# prec@10        0.000622
# recall@10      0.001195
# MAP@5          0.007051
# MAP@10         0.006456
# novelty       -0.031607
# serendipity   -0.000002
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K50_view-True
# prec@5         0.001511
# recall@5       0.003931
# prec@10        0.000820
# recall@10      0.004203
# MAP@5          0.002644
# MAP@10         0.002798
# novelty       -0.032061
# serendipity   -0.000006
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K60_view-False
# prec@5         0.002580
# recall@5       0.006172
# prec@10        0.000607
# recall@10      0.001124
# MAP@5          0.007049
# MAP@10         0.006446
# novelty       -0.031716
# serendipity   -0.000002
# dtype: float64
# =========================
#
# ===Сравнение с cosine_userknn_K60_view-True
# prec@5         0.001489
# recall@5       0.003875
# prec@10        0.000827
# recall@10      0.004232
# MAP@5          0.002601
# MAP@10         0.002760
# novelty       -0.032395
# serendipity   -0.000006
# dtype: float64
# =========================
#
# ===Сравнение с popular_mw_view-False
# prec@5         0.004892
# recall@5       0.013958
# prec@10        0.002465
# recall@10      0.012473
# MAP@5          0.009561
# MAP@10         0.009527
# novelty       -0.110420
# serendipity    0.000003
# dtype: float64
# =========================
#
# ===Сравнение с popular_mw_view-True
# prec@5         0.004892
# recall@5       0.013958
# prec@10        0.002465
# recall@10      0.012473
# MAP@5          0.009561
# MAP@10         0.009527
# novelty       -0.110417
# serendipity    0.000003
# dtype: float64
# =========================
#
# ===Сравнение с popular_view-False
# prec@5        -0.000319
# recall@5      -0.000609
# prec@10       -0.001363
# recall@10     -0.009260
# MAP@5          0.003462
# MAP@10         0.002453
# novelty       -0.015437
# serendipity    0.000003
# dtype: float64
# =========================
#
# ===Сравнение с popular_view-True
# prec@5        -0.001210
# recall@5      -0.002692
# prec@10       -0.001327
# recall@10     -0.008397
# MAP@5          0.000607
# MAP@10        -0.000124
# novelty       -0.004393
# serendipity    0.000003
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K30_view-False
# prec@5         0.002649
# recall@5       0.006968
# prec@10        0.000521
# recall@10      0.001815
# MAP@5          0.007181
# MAP@10         0.006564
# novelty       -0.025139
# serendipity   -0.000005
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K30_view-True
# prec@5         0.001561
# recall@5       0.004963
# prec@10        0.000498
# recall@10      0.003867
# MAP@5          0.003188
# MAP@10         0.003139
# novelty       -0.054900
# serendipity   -0.000009
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K40_view-False
# prec@5         0.002647
# recall@5       0.006945
# prec@10        0.000532
# recall@10      0.001897
# MAP@5          0.007178
# MAP@10         0.006579
# novelty       -0.026113
# serendipity   -0.000005
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K40_view-True
# prec@5         0.001575
# recall@5       0.005059
# prec@10        0.000542
# recall@10      0.004190
# MAP@5          0.003262
# MAP@10         0.003240
# novelty       -0.056080
# serendipity   -0.000010
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K50_view-False
# prec@5         0.002693
# recall@5       0.006895
# prec@10        0.000581
# recall@10      0.001887
# MAP@5          0.007161
# MAP@10         0.006574
# novelty       -0.025754
# serendipity   -0.000005
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K50_view-True
# prec@5         0.001698
# recall@5       0.005144
# prec@10        0.000665
# recall@10      0.004682
# MAP@5          0.003205
# MAP@10         0.003249
# novelty       -0.050752
# serendipity   -0.000010
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K60_view-False
# prec@5         0.002690
# recall@5       0.006875
# prec@10        0.000580
# recall@10      0.001819
# MAP@5          0.007150
# MAP@10         0.006557
# novelty       -0.026089
# serendipity   -0.000005
# dtype: float64
# =========================
#
# ===Сравнение с tfidf_userknn_K60_view-True
# prec@5         0.001694
# recall@5       0.005134
# prec@10        0.000657
# recall@10      0.004637
# MAP@5          0.003142
# MAP@10         0.003180
# novelty       -0.051312
# serendipity   -0.000010
# dtype: float64
# =========================

# %% [markdown]
# Лучшей модели большинством из моделей видны статистические различия, кроме всех моделей bmp (логично, потому что лучшая модель bmp с k = 60) и моделью tfidf, где для рекомендаций стоял флаг filter_viewed = True, что означает рекомендовать не одинаковые элементы для всех пользователей

# %% [markdown]
# # Обучение на всех имеющихся данных и формирование оффлайн рекомендаций

# %%
dataset = Dataset.construct(
    interactions_df=interactions,
    user_features_df=None,
    item_features_df=None
)

bmp25_k60_model = ImplicitItemKNNWrapperModel(BM25Recommender(K=60))
bmp25_k60_model.fit(dataset)

K_RECOS = 30
    
recos_offline_bmp25 = bmp25_k60_model.recommend(
    users=interactions[Columns.User].unique(),
    dataset=dataset,
    k=K_RECOS,
    filter_viewed=True,
)

# %%
recos_offline_bmp25.to_csv("../data/hw_3/bmp_25_k60_rectools.csv", index=False)

# %%
dataset = Dataset.construct(
    interactions_df=interactions,
    user_features_df=None,
    item_features_df=None
)

tfidf_k60_model = ImplicitItemKNNWrapperModel(TFIDFRecommender(K=60))
tfidf_k60_model.fit(dataset)

K_RECOS = 30
    
recos_offline_tfidf = tfidf_k60_model.recommend(
    users=interactions[Columns.User].unique(),
    dataset=dataset,
    k=K_RECOS,
    filter_viewed=True,
)

# %%
recos_offline_tfidf.to_csv("../data/hw_3/tfidf_k60_rectools.csv", index=False)

# %% [markdown]
# # Формирование рекомендаций для cold users

# %% [markdown]
# По моделям на основе популярного наилучшего качества достигали метрики по модели popular на основе количества уникальных пользователей взаимодействовавших с элементом, НО по среднему весу взаимодействия с элементами модель показывает по метрики новелти очень высокие результаты, поэтому стоит попробовать обе из моделей

# %%
dataset = Dataset.construct(
    interactions_df=interactions,
    user_features_df=None,
    item_features_df=None
)

popular_model = PopularModel()
popular_model.fit(dataset)

item_inv = dict(enumerate(interactions["item_id"].unique()))
recos_pop = []
for item_pop in popular_model.popularity_list[0]:
    recos_pop.append(item_inv[item_pop])

df_pop_recos = pd.DataFrame({"item_id": recos_pop})

df_pop_recos.to_csv("../data/hw_3/popular_item.csv", index=False)

# %%
dataset = Dataset.construct(
    interactions_df=interactions,
    user_features_df=None,
    item_features_df=None
)

popular_model_mw = PopularModel(popularity="mean_weight")
popular_model_mw.fit(dataset)

item_inv = dict(enumerate(interactions["item_id"].unique()))
recos_pop = []
for item_pop in popular_model_mw.popularity_list[0]:
    recos_pop.append(item_inv[item_pop])

df_pop_recos_mw = pd.DataFrame({"item_id": recos_pop})

df_pop_recos_mw.to_csv("../data/hw_3/popular_mean_weight_item.csv", index=False)

# %% [markdown]
# # Блендинг результатов моделей

# %% [markdown]
# Механизм блендинга будет выглядить следующим образом:
#
# 1. Берутся рекомендации, сделанные моделями tfidf и bmp25, конкатятся результаты, удялются дубликаты item-ов
# 2. Берется заготовленный датаест items c полями item_id и idf
# 3. смотрится idf, чем он выше, тем выше будет стоять item в выдаче
#
# Такой подход обусловлен тем, что idf показывает обратную частоту item, соответственно в выдаче наверх будут попадать item, с которым меньшее количество раз взаимодейстовали пользователи, т.е. в перспективе такой подход может предлагать item, с которыми ни один пользователь не взаимодействовал или взаимодействовали очень мало, т.е. может решиться проблема длинного хвоста.

# %%
import pandas as pd

# %%
df_bmp_recs = pd.read_csv("../data/hw_3/bmp_25_k60_rectools.csv")
df_tfidf_recs = pd.read_csv("../data/hw_3/tfidf_k60_rectools.csv")

# %%
pd.concat([df_bmp_recs.head(), df_bmp_recs.tail()])
# Out:
#           user_id  item_id         score  rank
# 0          176549    13865  8.899597e+10     1
# 1          176549    10440  8.153085e+10     2
# 2          176549    15297  7.204604e+10     3
# 3          176549     3734  6.953473e+10     4
# 4          176549     4151  4.674591e+10     5
# 28862258   697262     5434  1.615419e+10    26
# 28862259   697262     1132  1.605160e+10    27
# 28862260   697262     7476  1.566697e+10    28
# 28862261   697262    11237  1.546907e+10    29
# 28862262   697262    12995  1.542308e+10    30

# %%
pd.concat([df_tfidf_recs.head(), df_tfidf_recs.tail()])
# Out:
#           user_id  item_id         score  rank
# 0          176549    11749  13575.660185     1
# 1          176549    16270  11946.872708     2
# 2          176549    11985  11355.693119     3
# 3          176549    13159  10375.500647     4
# 4          176549    15266  10269.019690     5
# 28862258   697262     6192   1294.342414    26
# 28862259   697262    11640   1277.332333    27
# 28862260   697262     7476   1262.919377    28
# 28862261   697262       14   1213.499281    29
# 28862262   697262     3784   1200.347785    30

# %%
del df_tfidf_recs['rank'], df_bmp_recs['rank'], df_tfidf_recs['score'], df_bmp_recs['score']

# %%
df_all_recs = pd.concat(
    [
        df_bmp_recs, df_tfidf_recs
    ],
    ignore_index=True
).sort_values(
    ["user_id"], ascending=False
).drop_duplicates(
    ["user_id", "item_id"]
).reset_index(drop=True)

pd.concat([df_all_recs.head(20), df_all_recs.tail(20)])
# Out:
#           user_id  item_id
# 0         1097557     1132
# 1         1097557     5658
# 2         1097557      142
# 3         1097557     3734
# 4         1097557    16228
# 5         1097557    12192
# 6         1097557    13865
# 7         1097557     2657
# 8         1097557     9728
# 9         1097557     4880
# 10        1097557    11778
# 11        1097557     9996
# 12        1097557     8636
# 13        1097557     3935
# 14        1097557     5803
# 15        1097557     4457
# 16        1097557     1844
# 17        1097557     6382
# 18        1097557     4716
# 19        1097557     4495
# 41023372        0     3734
# 41023373        0     3935
# 41023374        0     7417
# 41023375        0     4495
# 41023376        0     6382
# 41023377        0     5803
# 41023378        0     1844
# 41023379        0    11778
# 41023380        0     8636
# 41023381        0     9996
# 41023382        0     2657
# 41023383        0    16228
# 41023384        0     4880
# 41023385        0    13865
# 41023386        0      142
# 41023387        0     6443
# 41023388        0     4740
# 41023389        0     6809
# 41023390        0    10440
# 41023391        0    14901

# %%
item_idf = pd.read_csv("../data/kion_train/items_idf.csv")
print(item_idf.shape)
item_idf.head()
# Out:
# (15706, 2)
#    index       idf
# 0   9506  7.150811
# 1   1659  8.524953
# 2   7107  5.821207
# 3   7638  8.407093
# 4   6686  7.778734

# %%
df_all_recs = df_all_recs.merge(
    item_idf, left_on='item_id', right_on='index', how='left'
).sort_values(['user_id', 'idf'], ascending=False)

pd.concat([df_all_recs.head(20), df_all_recs.tail(20)])
# Out:
#           user_id  item_id  index       idf
# 14        1097557     5803   5803  6.840585
# 17        1097557     6382   6382  6.806090
# 25        1097557     7476   7476  6.545666
# 18        1097557     4716   4716  6.480408
# 34        1097557       14     14  6.467549
# 24        1097557    11640  11640  6.318255
# 21        1097557     5434   5434  6.226266
# 0         1097557     1132   1132  6.183141
# 10        1097557    11778  11778  6.134312
# 13        1097557     3935   3935  6.067242
# 23        1097557     6192   6192  6.038563
# 1         1097557     5658   5658  6.025091
# 26        1097557     3784   3784  5.990008
# 4         1097557    16228  16228  5.756312
# 31        1097557     7417   7417  5.715013
# 32        1097557     7829   7829  5.615193
# 19        1097557     4495   4495  5.563930
# 22        1097557    14431  14431  5.558556
# 15        1097557     4457   4457  5.548639
# 28        1097557    12995  12995  5.495888
# 41023374        0     7417   7417  5.715013
# 41023361        0     7829   7829  5.615193
# 41023375        0     4495   4495  5.563930
# 41023358        0    14431  14431  5.558556
# 41023364        0     4457   4457  5.548639
# 41023363        0    12995  12995  5.495888
# 41023378        0     1844   1844  5.419019
# 41023366        0    11237  11237  5.365593
# 41023360        0     7571   7571  5.267906
# 41023388        0     4740   4740  5.078522
# 41023380        0     8636   8636  5.041418
# 41023381        0     9996   9996  4.992277
# 41023389        0     6809   6809  4.917360
# 41023386        0      142    142  4.801620
# 41023384        0     4880   4880  4.610045
# 41023382        0     2657   2657  4.392592
# 41023372        0     3734   3734  4.306872
# 41023365        0     4151   4151  4.111983
# 41023385        0    13865  13865  3.825227
# 41023390        0    10440  10440  3.333947

# %%
del df_all_recs['index'], df_all_recs['idf']

# %%
count_recs_by_users = df_all_recs.user_id.value_counts()
print(f"Количество пользователей, у которорых рекомендаций меньше 10: {len(count_recs_by_users[count_recs_by_users < 10])}")
# Out:
# Количество пользователей, у которорых рекомендаций меньше 10: 21

# %% [markdown]
# Для пользователей, у которых будет меньше рекомендаций, чем k_recs, рекомендации **будут пополняться популярным**

# %%
df_popular = pd.read_csv('../data/hw_3/popular_item.csv')
users_need = count_recs_by_users[count_recs_by_users < 10].index

# %%
k_recs = 10
users, recs = [], []
for user, count in dict(count_recs_by_users[count_recs_by_users < 10]).items():
    need_recs = k_recs - count
    users.extend([user for _ in range(need_recs)])
    recs.extend(df_popular["item_id"][:need_recs].to_list())

# %%
df_all_recs
# Out:
#           user_id  item_id
# 0         1097557     5803
# 1         1097557     6382
# 2         1097557     7476
# 3         1097557     4716
# 4         1097557       14
# ...           ...      ...
# 41023387        0     2657
# 41023388        0     3734
# 41023389        0     4151
# 41023390        0    13865
# 41023391        0    10440
#
# [41023392 rows x 2 columns]

# %%
df_need = pd.DataFrame({"user_id": users, "item_id": recs})
df_all_recs = pd.concat([df_all_recs, df_need], ignore_index=True).sort_values("user_id")

# %%
count_recs_by_users = df_all_recs.user_id.value_counts()
print(f"Количество пользователей, у которорых рекомендаций меньше 10: {len(count_recs_by_users[count_recs_by_users < 10])}")
# Out:
# Количество пользователей, у которорых рекомендаций меньше 10: 0

# %%
df_all_recs.to_csv("../data/hw_3/blending_tfidf_bmp25_idf_rectools.csv", index=False)

# %% [markdown]
# Offline рекомендации не работали с блендингом, решил уменьшить количество рекомендаций для одного юзера до 10 и заработало

# %%
df_all_recs['rank'] = df_all_recs.groupby('user_id').cumcount() + 1
df_all_recs_top10 = df_all_recs[df_all_recs['rank'] <= 10]
del df_all_recs_top10['rank']
df_all_recs_top10.shape
# Out:
# (9621050, 2)

# %%
df_all_recs_top10.to_csv("../data/hw_3/blending_tfidf_bmp25_idf_rectools_10.csv", index=False)
